# %%
import pandas as pd
df = pd.read_csv(r"E:\Marketing Assignment\People Survey\responses.csv")
df.head(10)
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
# 5    5.0                       3.0    2.0   3.0      2.0              3.0
# 6    5.0                       5.0    5.0   3.0      1.0              2.0
# 7    5.0                       3.0    3.0   2.0      1.0              2.0
# 8    5.0                       3.0    3.0   1.0      1.0              2.0
# 9    5.0                       3.0    2.0   5.0      2.0              2.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0      1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# ...

# %%
df.columns
# Out:
# Index(['Music', 'Slow songs or fast songs', 'Dance', 'Folk', 'Country',
#        'Classical music', 'Musical', 'Pop', 'Rock', 'Metal or Hardrock',
#        ...
#        'Age', 'Height', 'Weight', 'Number of siblings', 'Gender',
#        'Left - right handed', 'Education', 'Only child', 'Village - town',
#        'House - block of flats'],
#       dtype='object', length=150)

# %%
#Extracting only necessary columns
new_order = ['Age', 'Education', 'Gender', 'Smoking', 'Alcohol','Energy levels', 'Life struggles', 
             'Number of friends', 'Happiness in life']

new_df = df[new_order].head(250)
new_df.columns
# Out:
# Index(['Age', 'Education', 'Gender', 'Smoking', 'Alcohol', 'Energy levels',
#        'Life struggles', 'Number of friends', 'Happiness in life'],
#       dtype='object')

# %%
new_df.head(250)
# Out:
#       Age                Education  Gender        Smoking         Alcohol  \
# 0    20.0  college/bachelor degree  female   never smoked     drink a lot
# 1    19.0  college/bachelor degree  female   never smoked     drink a lot
# 2    20.0         secondary school  female  tried smoking     drink a lot
# 3    22.0  college/bachelor degree  female  former smoker     drink a lot
# 4    20.0         secondary school  female  tried smoking  social drinker
# ..    ...                      ...     ...            ...             ...
# 245  19.0           primary school  female  tried smoking  social drinker
# 246  27.0           masters degree    male  tried smoking           never
# 247  22.0  college/bachelor degree  female  former smoker     drink a lot
# 248  19.0         secondary school  female  tried smoking  social drinker
# 249  19.0         secondary school  female   never smoked  social drinker
#
#      Energy levels  Life struggles  Number of friends  Happiness in life
# ...

# %%
specific_columns = ['Age', 'Education', 'Gender', 'Smoking', 'Alcohol','Energy levels', 'Life struggles', 
                    'Number of friends', 'Happiness in life']

# Loop through each specified column and print unique values and their counts
for column in specific_columns:
    if column in df.columns:
        unique_values = df[column].unique()
        value_counts = df[column].value_counts()
        print(f"\nColumn: {column}")
        print(f"Unique values: {unique_values}")
        print(f"Frequency of unique values:\n{value_counts}")
    else:
        print(f"\nColumn: {column} is not present in the DataFrame")
# Out:
# Column: Age
# Unique values: [20. 19. 22. 18. 17. 24. 25. 27. 21. 23. 26. 28. 16. 15. nan 29. 30.]
# Frequency of unique values:
# 19.0    210
# 20.0    194
# 21.0    127
# 18.0    123
# 22.0     84
# 17.0     53
# 23.0     47
# 25.0     30
# 16.0     29
# 24.0     28
# 28.0     17
# 26.0     15
# 27.0     14
# 15.0     11
# 29.0     11
# 30.0     10
# Name: Age, dtype: int64
#
# Column: Education
# Unique values: ['college/bachelor degree' 'secondary school' 'primary school'
#  'masters degree' 'doctorate degree' 'currently a primary school pupil'
#  nan]
# Frequency of unique values:
# secondary school                    621
# college/bachelor degree             212
# masters degree                       81
# primary school                       80
# currently a primary school pupil     10
# doctorate degree                      5
# Name: Education, dtype: int64
#
# Column: Gender
# Unique values: ['female' 'male' nan]
# Frequency of unique values:
# female    593
# male      411
# ...

# %%
new_df.dtypes
# Out:
# Age                  float64
# Education             object
# Gender                object
# Smoking               object
# Alcohol               object
# Energy levels        float64
# Life struggles       float64
# Number of friends      int64
# Happiness in life    float64
# dtype: object

# %%
#Dropping all missing values and cleaning data
new_df = new_df.dropna()

# %%
new_df.to_csv(r"E:\Marketing Assignment\People Survey\Preprocessed.xlsx", index=False)
